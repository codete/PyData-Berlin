# %%
# %matplotlib inline

# %% [markdown]
# # Border removal

# %%
from skimage import io

# %%
image_rgb = io.imread("./data/blue-veil/ISIC_0054527.jpg")
io.imshow(image_rgb)

# %%
from melanoma.border import remove_border

borderless_image_rgb = remove_border(image_rgb)
io.imshow(borderless_image_rgb)
